# %%
from urllib.request import urlopen

import textract
import nltk
#str1 = "/Users/prajwalseth1/Desktop/Ashoka/sem2/Political thought in the age of Nationalism/midterm essay/dump/word/"
#str1 = "/Users/prajwalseth1/Desktop/Ashoka/sem2/Great Books/Our Inner ape/"
#str1 = "/Users/prajwalseth1/Desktop/Ashoka/sem2/Political thought in the age of Nationalism/midterm essay/readings/word/"
#str1 = "/Users/prajwalseth1/Desktop/Ashoka/sem2/Political thought in the age of Nationalism/Week 6/Tuesday/dump/"
#str1 = "/Users/prajwalseth1/Desktop/Ashoka/sem2/Great Books/Week 8/"
#str1 = "/Users/prajwalseth1/Desktop/Ashoka/sem2/Political thought in the age of Nationalism/final essay/dump/"
#str1 = "/Users/prajwalseth1/Desktop/Ashoka/sem2/Human flourishing/Week 12/"
#str1 = "/Users/prajwalseth1/Desktop/Ashoka/sem2/Human flourishing/Week 9/dump/"
str1 = "/Users/prajwalseth1/Desktop/CCS Internship/aggregators/journals/dump/"
str1 = "/Users/prajwalseth1/Desktop/books/to read/"
str1 = "/Users/prajwalseth1/Desktop/books/to read/dump/"
str1 = '/Users/prajwalseth1/Desktop/CCS Internship/aggregators/June 28/'
str1 = '/Users/prajwalseth1/Desktop/Ashoka/sem2/Ashoka-Stanford Megacity program/Readings/Aug 17/dump/'
str1 = '/Users/prajwalseth/Desktop/Ashoka/sem3/Mind and Behaviour/Week 1/Monday/'
#str1 = '/Users/prajwalseth1/Desktop/books 2/'
#str1 = "/Users/prajwalseth1/Desktop/dump/"

str2 = "Rosen.pdf"
str = str1+str2
text = textract.process(str)
#url = "https://newrepublic.com/article/125706/benedict-anderson-man-without-country"
#html = urlopen(url).read()
#text[:500]

from readability.readability import Document
from bs4 import BeautifulSoup

readable_article = Document(text).summary()
readable_title = Document(text).title()
soup = BeautifulSoup((text), "lxml")
#print ('*** TITLE *** \n\"' + readable_title + '\"\n')
#print ('*** CONTENT *** \n\"' + soup.text[:500] + '[...]\"')

tokens = [word for sent in nltk.sent_tokenize(soup.text) for word in nltk.word_tokenize(sent)]

from nltk.stem.snowball import SnowballStemmer

stemmer = SnowballStemmer("english")
stemmed_tokens = [stemmer.stem(t) for t in tokens]

import datetime, re, sys
from sklearn.feature_extraction.text import TfidfVectorizer

def tokenize_and_stem(text):
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    stems = [stemmer.stem(t) for t in filtered_tokens]
    return stems

token_dict = {}

for article in text:
    token_dict[article] = soup.text
#for article in reuters.fileids():
 #   token_dict[article] = reuters.raw(article)
        
tfidf = TfidfVectorizer(tokenizer=tokenize_and_stem, stop_words='english', decode_error='ignore')
sys.stdout.flush()

tdm = tfidf.fit_transform(token_dict.values()) # this can take some time (about 60 seconds on my machine)

from random import randint

feature_names = tfidf.get_feature_names()




import math
from __future__ import division
import collections

article_id = 0
#article_text = reuters.raw(reuters.fileids()[article_id])

article_text = soup.text
sent_scores = []
for sentence in nltk.sent_tokenize(article_text):
    
    score = 0
    sent_tokens = tokenize_and_stem(sentence)
    for token in (t for t in sent_tokens if t in feature_names):
        score += tdm[article_id, feature_names.index(token)]
    
    if len(sent_tokens) ==0:
        continue;
    
    else:
        sent_scores.append((score / len(sent_tokens), sentence))

summary_length = int(math.ceil(len(sent_scores) / (3)))
var = 0
order = {}
sent_scores.sort(key=lambda sent: sent[0], reverse=True)
print ('*** SUMMARY ***')
for summary_sentence in sent_scores[:summary_length]:
    var = article_text.find(summary_sentence[1])
    order[var] = summary_sentence[1]
    # print (summary_sentence[1])
ordered = collections.OrderedDict(sorted(order.items()))
for k, v in ordered.items(): 
    print(v) #end = " ")
print('\n')
print ('\n*** ORIGINAL ***')
print (article_text)
# Out:
# *** SUMMARY ***
# When you read a philosophical text, your
# main job is to identify and assess the author’s arguments.
# What is an argument?
# What is a good argument?
# How can we
# tell whether an argument is a good one?
# What Is an Argument?
# An argument is a sequence of statements.
# This is the claim that the argument seeks to establish or support.
# An
# argument will usually include one or more premises: statements that are simply
# asserted without proof in the context of the present argument but which may be
#
# 10 69
#
# 1070
#
# A B r i e f G u i d e to Lo g i c a n d A r g u m e n tat i o n
#
# supported by arguments given elsewhere.
# Consider, for example, the following
# argument for the existence of God:
# ARGUMENT A
#
# (1) The Bible says that God exists.
# (3) Therefore, God exists.
# Therefore, God exists.
# Now, anyone who propounds this argument will probably realize that his premises are controversial, so he may seek to defend them by independent arguments.
# ...

# %%
import nltk

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True
